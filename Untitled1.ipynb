# %%
from gvol import GVol

# %%
from gvol import Amberdata

# %%
amberdata_client = Amberdata(api_key='UAK615004150ad5a46f828e9b9339c133df')

# %%
amberdata_client.get_tickers(exchange='okex', currency='BTC', startDate='2024-04-01T00:00:00', endDate='2024-04-29T00:00:00', timeInterval='day').sort_values('timestamp')
# Out:
#                      timestamp         exchangeTimestamp exchange  \
# 0     2024-04-17T00:00:00.000Z  2024-04-17T00:00:02.000Z     okex
# 437   2024-04-17T00:00:00.000Z  2024-04-17T00:00:00.000Z     okex
# 438   2024-04-17T00:00:00.000Z  2024-04-17T00:00:00.000Z     okex
# 439   2024-04-17T00:00:00.000Z  2024-04-17T00:00:06.000Z     okex
# 440   2024-04-17T00:00:00.000Z  2024-04-17T00:00:00.000Z     okex
# ...                        ...                       ...      ...
# 7728  2024-04-28T00:00:00.000Z  2024-04-28T00:00:00.000Z     okex
# 7729  2024-04-28T00:00:00.000Z  2024-04-28T00:00:54.000Z     okex
# 7730  2024-04-28T00:00:00.000Z  2024-04-28T00:00:07.000Z     okex
# 7842  2024-04-28T00:00:00.000Z  2024-04-28T00:00:00.000Z     okex
# 8195  2024-04-28T00:00:00.000Z  2024-04-28T00:00:00.000Z     okex
#
#                    instrument         instrumentNormalized currency  \
# 0      BTC-USD-240417-78000-C   OKEX-BTC-17APR24-78000.0-C      BTC
# ...

# %%
amberdata_client.get_instrument_information(exchange='deribit')

# %%
amberdata_client.get_term_structure(currency = 'BTC', exchange='deribit')
