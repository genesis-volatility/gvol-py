# %%
import pandas as pd

# %%
from gvol import AMBERDATA

# %%
import sys
print(sys.executable)
# Out:
# /Users/fabiobassani/Documents/AMBERDATA/github/gvol-py/gvolpy/bin/python

# %%
AD_client = AMBERDATA(api_key="UAK615004150ad5a46f828e9b9339c133df")

# %%
AD_client.get_instrument_information()
# Out:
# {"status":200,"title":"OK","description":"Successful request","payload":{"data":[{"endDate":1714234140000,"exchange":"okex","instrument":"OKEX-ETH-27DEC24-16000.0-C","nativeInstrument":"ETH-USD-241227-16000-C","multiplier":0.1,"putCall":"C","expiration":1735286400000,"currency":"ETH","strike":16000},{"endDate":1714234140000,"exchange":"okex","instrument":"OKEX-BTC-27SEP24-5000.0-C","nativeInstrument":"BTC-USD-240927-5000-C","multiplier":0.01,"putCall":"C","expiration":1727424000000,"currency":"B
#             endDate exchange                        instrument  \
# 0     1714234140000     okex        OKEX-ETH-27DEC24-16000.0-C
# 1     1714234140000     okex         OKEX-BTC-27SEP24-5000.0-C
# 2     1714234140000     okex        OKEX-BTC-10MAY24-72000.0-C
# 3     1714234140000     okex        OKEX-BTC-17MAY24-54000.0-P
# 4     1714234140000     okex        OKEX-BTC-10MAY24-58000.0-C
# ...             ...      ...                               ...
# ...
